# %%
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt 
import nltk
import lyricsgenius as lg
import string
import json
import time

# %%
#API access token

genius = lg.Genius('acf6_fdssOiXTe_GUSCltC1r4lk7riRcNWZTU5vjM63F4XLgE4d9QnZ6zZGyohW1', skip_non_songs=True, excluded_terms=["(Remix)", "(Live)"], remove_section_headers=True)

# %%
metal_albums_df = pd.read_csv('/work/lyrical_analysis/assets/metal_albums.csv')

artist_list=list(metal_albums_df['artist'].unique())

# %%
#### I think this may get us what we need, except for the release_date / year.  Can we use another API or use Genius in a different way to get the 
#### year of each artist's first song then join the two dataframes? 

artist_albums = {'artists': []}

# def songsAreSame(s1, s2):    
#     # Idea credit: https://bigishdata.com/2016/10/25/talkin-bout-trucks-beer-and-love-in-country-songs-analyzing-genius-lyrics/
#     # Compare lyric content using SequenceMatcher
#     seqA = sm(None, s1.lyrics, s2['lyrics'])
#     seqB = sm(None, s2['lyrics'], s1.lyrics)
#     return seqA.ratio() > 0.5 or seqB.ratio() > 0.5

# def songInArtist(new_song):    
    # # artist_lyrics is global (works in Jupyter notebook)
    # for song in artist_lyrics['artists'][-1]['songs']:
    #     if songsAreSame(new_song, song):
    #         return True
    # return False

def downloadAlbums(artist_names, max_songs=4, filename="/work/lyrical_analysis/albums"):
    # Use the Genius API to get each artist's lyrics
    found_artists = {}

    start = time.time()

    while True:
        try:      
            for n, name in enumerate(artist_names):
                print("\n--------")
                # try:        
                if name not in found_artists:
                    artist = genius.search_albums(name,max_songs=max_songs)
                    artist_albums['artists'].append({})
                    artist_albums['artists'][-1]['artist'] = artist.name                            
                    artist_albums['artists'][-1]['albums'] = []            
                    for album in artist.albums:
                    #if not songInArtist(song): # This takes way too long! It's basically O(n^2), can I do better?
                        #artist_albums['artists'][-1]['songs'].append({})
                        #artist_albums['artists'][-1]['songs'][-1]['title'] = song.title
                        artist_albums['artists'][-1]['songs'][-1]['tracks'] = album.tracks
                        artist_albums['artists'][-1]['songs'][-1]['year'] = album.release_date_components
                        #artist_albums['artists'][-1]['songs'][-1]['lyrics'] = song.lyrics                
                        # artist_albums['artists'][-1]['songs'][-1]['image'] = song.song_art_image_url
                        # artist_albums['artists'][-1]['songs'][-1]['artist'] = name
                        # artist_albums['artists'][-1]['songs'][-1]['json'] = song._body
                    #     else:
                    #         print("SKIPPING \"{}\", already found in artist collection.".format(song.title))
                    found_artists[name] = (name, len(artist_albums['artists'])-1)
                else:
                    # Store reference to artist location in dict, if artist previously found
                    artist_albums['artists'][-1] = found_artists[name]
                # except Exception as e:
                    # print(e)
                    # print('Skipping "{}" due to error.'.format(name))

                # Every other artist write the JSON object to disk as a backup
                if n % 2 == 0:
                    with open(filename + '_temp' '.json', 'w') as outfile:
                        json.dump(artist_albums, outfile)

            # Final write of the JSON object
            with open(filename + '.json', 'w') as outfile:
                json.dump(artist_albums, outfile)
        except:
            pass

    
    end = time.time()
    print("Time elapsed: {} hours".format((end-start)/60.0/60.0))

downloadAlbums(['Metallica','Megadeth','Opeth'])
# Out:
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
#
# --------
# ...

# %%
song = (genius.search_song(title='Nothing Else Matters',artist='Metallica',get_full_info=True))

#example_dict.get('key1', {}).get('key2')

song
# Out:
# Searching for "Nothing Else Matters" by Metallica...
# Done.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_437/116433273.py in <module>
#       3 #example_dict.get('key1', {}).get('key2')
#       4
# ----> 5 song.year
#
# AttributeError: 'Song' object has no attribute 'year'

# %%
artist_sorder = {'artists': []}


def get_sorder(arr)

    found_artists = {}

    while True:
        try:
            for n, name in enumerate(arr):
                print('\n---------')
                for name not in found_artists:
                        artist_id = (genius.search_artist(arr,max_songs=0))
                        ar_id = songs.id

                        songs = (genius.artist_songs(ar_id,sort="release_date"))

                        artist_sorder['artists'].append({})
                        artist_sorder['artists'][-1]['artist'] = arr
                        for 






    songs = (genius.artist_songs(ar_id,sort="release_date"))
    song_info = songs.get('songs')
    more_info = song_info[0]
    more_info.get('title')





    while True:
        try:      
            for n, name in enumerate(artist_names):
                print("\n--------")
                # try:        
                if name not in found_artists:
                    artist = genius.search_albums(name,max_songs=max_songs)
                    artist_albums['artists'].append({})
                    artist_albums['artists'][-1]['artist'] = artist.name                            
                    artist_albums['artists'][-1]['albums'] = []            
                    for album in artist.albums:
                    #if not songInArtist(song): # This takes way too long! It's basically O(n^2), can I do better?
                        #artist_albums['artists'][-1]['songs'].append({})
                        #artist_albums['artists'][-1]['songs'][-1]['title'] = song.title
                        artist_albums['artists'][-1]['songs'][-1]['tracks'] = album.tracks
                        artist_albums['artists'][-1]['songs'][-1]['year'] = album.release_date_components
                        #artist_albums['artists'][-1]['songs'][-1]['lyrics'] = song.lyrics                
                        # artist_albums['artists'][-1]['songs'][-1]['image'] = song.song_art_image_url
                        # artist_albums['artists'][-1]['songs'][-1]['artist'] = name
                        # artist_albums['artists'][-1]['songs'][-1]['json'] = song._body
                    #     else:
                    #         print("SKIPPING \"{}\", already found in artist collection.".format(song.title))
                    found_artists[name] = (name, len(artist_albums['artists'])-1)
                else:
                    # Store reference to artist location in dict, if artist previously found
                    artist_albums['artists'][-1] = found_artists[name]
                # except Exception as e:
                    # print(e)
                    # print('Skipping "{}" due to error.'.format(name))

                # Every other artist write the JSON object to disk as a backup
                if n % 2 == 0:
                    with open(filename + '_temp' '.json', 'w') as outfile:
                        json.dump(artist_albums, outfile)

            # Final write of the JSON object
            with open(filename + '.json', 'w') as outfile:
                json.dump(artist_albums, outfile)
        except:
            pass

    
    end = time.time()
    print("Time elapsed: {} hours".format((end-start)/60.0/60.0))


##### final product to be {artist: 'Metallica', sorder: [list of songs released in order]}
##### search artist, pull title out from songs and add it to list within dict.  Reverse list
# Out:
# Searching for songs by Megadeth...
#
# Done. Found 0 songs.
# 'No Peace'

# %%
arr = 'Megadeth'

artist_id = (genius.search_artist(arr,max_songs=0,per_page=50))
songs
# Out:
# Searching for songs by Megadeth...
#
# Done. Found 0 songs.
# {'songs': [{'annotation_count': 0,
#    'api_path': '/songs/6574745',
#    'full_title': 'No Peace by\xa0Insolent\xa0Myth (Ft.\xa0Dave\xa0Mustaine)',
#    'header_image_thumbnail_url': 'https://images.genius.com/432e9b135b97036fa36d8070a637a0ce.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/432e9b135b97036fa36d8070a637a0ce.1000x1000x1.png',
#    'id': 6574745,
#    'lyrics_owner_id': 12680311,
#    'lyrics_state': 'complete',
#    'path': '/Insolent-myth-no-peace-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/432e9b135b97036fa36d8070a637a0ce.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/432e9b135b97036fa36d8070a637a0ce.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 0, 'hot': False},
#    'title': 'No Peace',
#    'title_with_featured': 'No Peace (Ft.\xa0Dave\xa0Mustaine)',
# ...

# %%
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
from tqdm import tqdm_notebook
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = 'be7d854fe1424b9ba2c95fa27adac6d8'
client_secret = 'ed4563d327264da3940e2c7ab74140bb'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API


artist_list = ['Megadeth','Opeth']

def artist_tracks(artists):
    
    '''
    Takes a list of artist names, iterates through their Spotify albums, checks for 
    duplicate albums, then appends all the tracks in those albums to a list of lists
    '''
    
    # Each list in this list will be a track and its features
    tracks = []
    
    
    for artist in artist_list:
        
        # Get the artist URI (a unique ID)
        artist_uri = sp.search(artist)['tracks']['items'][0]['artists'][0]['uri']

        # Spotify has a lot of duplicate albums, but we'll cross-reference them with this list to avoid extra loops
        album_checker = []
        
        # The starting point of our loop of albums for those artists with more than 50
        n = 0
        
        # Note the album_type = 'album'. This discounts singles, compilations and collaborations
        while len(sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']) > 0:
            
            # Avoid overloading Spotify with requests by assigning the list of album dictionaries to a variable
            dict_list = sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']
            
            for i, album in (enumerate(artist_list)):

                # Add the featured artists for the album in question to the checklist
                check_this_album = [j['name'] for j in dict_list[i]['artists']]
                # And the album name
                check_this_album.append(dict_list[i]['name'])
                # And its date
                check_this_album.append(dict_list[i]['release_date'])

                # Only continue looping if that album isn't in the checklist
                if check_this_album not in album_checker:
                    
                    # Add this album to the checker
                    album_checker.append(check_this_album)
                    # For every song on the album, get its descriptors and features in a list and add to the tracklist
                    tracks.extend([[artist, album['name'], album['uri'], song['name'],

                      album['release_date']] + list(sp.audio_features(song['uri'])[0].values()) 
                                   for song in sp.album_tracks(album['uri'])['items']])
            
            # Go through the next 50 albums (otherwise we'll get an infinite while loop)
            n += 50

    return tracks

artist_tracks(artist_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_145/4224333466.py in <module>
#      65     return tracks
#      66
# ---> 67 artist_tracks(artist_list)
#
# /tmp/ipykernel_145/4224333466.py in artist_tracks(artists)
#      58
#      59                       album['release_date']] + list(sp.audio_features(song['uri'])[0].values())
# ---> 60                                    for song in sp.album_tracks(album['uri'])['items']])
#      61
#      62             # Go through the next 50 albums (otherwise we'll get an infinite while loop)
#
# TypeError: string indices must be integers

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8bd17c4e-3ac7-47d3-9d46-79b1a90f90dd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
